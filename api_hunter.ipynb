# %%
# Script fetches hunter.io data by API
# Creation date: 18 AUG 2023
# Last modification: 18 AUG 2023
# Made by: Kamil Smolag

import requests
import pandas as pd
import datetime as dt

def get_hunter_emails_from_domain(domain, api_key):
    url = f"https://api.hunter.io/v2/domain-search?domain={domain}&type=personal&department=executive,it,management,operations&api_key={api_key}"
    response = requests.get(url)
    data = response.json()
    domain_emails = []
    if data.get("data", {}).get("emails"):
        domain_emails.extend(data['data']['emails'])
        return domain_emails
    else:
        return []

def get_uplead_emails_from_domain(domain, api_key):
    pass

def run_hunter_api():
    api_key_hunter = '3d113e7839b6c17a4b0aa48c4164f8c040c49f6b'
    filename = "websites_only_Legal_17-Aug-2023.csv"
    data = pd.read_csv(filename)
    
    all_emails_data = []
    for domain in data['Website']:
        hunter_emails = get_hunter_emails_from_domain(domain, api_key_hunter)
        # Hunter.io loop
        for email in hunter_emails:
            email_data = {
                'Platform': 'Hunter',
                'Domain': domain,
                'Email': email['value'],
                'First Name': email['first_name'],
                'Last Name': email['last_name'],
                'Phone number': email['phone_number'],
                'Position': email['position'],
                'Department': email['department'],
                'Twitter handle': email['twitter'],
                'LinkedIn URL': email['linkedin'],
                'Verification': email['verification']['status'],
            }
            all_emails_data.append(email_data)
    
    results_df = pd.DataFrame(all_emails_data)
    print(results_df)
    current_date = dt.datetime.now().strftime("%d-%b-%Y")
    results_df.to_excel(f"emails_{current_date}_Hunter.xlsx", index=False)
    
    print(f"Total {len(all_emails_data)} emails found.")

if __name__ == "__main__":
    run_hunter_api()
# Out:
#    Platform                 Domain                            Email  \
# 0    Hunter  innovativesystems.com  nmarshall@innovativesystems.com
# 1    Hunter               sphs.org                 ageibel@sphs.org
# 2    Hunter           lgtlegal.com             lbodnar@lgtlegal.com
# 3    Hunter              axinn.com                mbecker@axinn.com
# 4    Hunter            yorkson.com               gbreck@yorkson.com
# 5    Hunter            yorkson.com           greichwald@yorkson.com
# 6    Hunter       greenbaumlaw.com        dserviss@greenbaumlaw.com
# 7    Hunter       greenbaumlaw.com       nisaacson@greenbaumlaw.com
# 8    Hunter       greenbaumlaw.com         tsenter@greenbaumlaw.com
# 9    Hunter       greenbaumlaw.com         ekaller@greenbaumlaw.com
# 10   Hunter                vnf.com               mgoodstein@vnf.com
# 11   Hunter                vnf.com               sleverette@vnf.com
# 12   Hunter                vnf.com                  mvivian@vnf.com
# 13   Hunter                vnf.com                jlarrabee@vnf.com
# 14   Hunter         teamavalon.com     jill.martucci@teamavalon.com
# 15   Hunter         teamavalon.com   jason.schroeder@teamavalon.com
# 16   Hunter         teamavalon.com         jim.babak@teamavalon.com
# 17   Hunter         teamavalon.com    kyle.cavalieri@teamavalon.com
# 18   Hunter         teamavalon.com        marty.bohn@teamavalon.com
# 19   Hunter         teamavalon.com     kevin.pursley@teamavalon.com
# 20   Hunter         teamavalon.com       steve.huber@teamavalon.com
# 21   Hunter         teamavalon.com      troy.richard@teamavalon.com
# 22   Hunter         teamavalon.com              mike@teamavalon.com
# 23   Hunter         teamavalon.com             lewis@teamavalon.com
# 24   Hunter          jconnelly.com             asmith@jconnelly.com
# 25   Hunter          jconnelly.com             aflach@jconnelly.com
# 26   Hunter          jconnelly.com          ejohnston@jconnelly.com
# 27   Hunter          jconnelly.com           lsimpson@jconnelly.com
# 28   Hunter          jconnelly.com            laldape@jconnelly.com
# 29   Hunter          jconnelly.com         aattanasio@jconnelly.com
# 30   Hunter          jconnelly.com         kpellicone@jconnelly.com
#
#    First Name  Last Name     Phone number                        Position  \
# 0        Neil   Marshall             None                 Partner Manager
# 1      Amanda     Geibel             None                      Supervisor
# 2        Lisa     Bodnar             None      Director Of Administration
# 3     Matthew     Becker             None                Managing Partner
# 4        Greg      Breck             None              Compliance Officer
# 5        Gail  Reichwald             None                             CEO
# 6      Daniel    Serviss  +1 973 539 4151               Managing Director
# 7       Nancy   Isaacson  +1 973 535 1600                       Assistant
# 8      Thomas     Senter  +1 732 476 2650                             CEO
# 9       Emily     Kaller             None    Executive Director President
# 10    Michael  Goodstein  +1 202 298 1923                Managing Partner
# 11       Sara  Leverette  +1 206 802 3846           Senior Policy Advisor
# 12    Matthew     Vivian             None                         Manager
# 13      Jason   Larrabee  +1 202 298 1881           Senior Policy Advisor
# 14       Jill   Martucci             None        Executive Vice President
# 15      Jason   Schröder             None         Regional Vice President
# 16        Jim      Babak             None          Director Of Operations
# 17       Kyle  Cavalieri             None                             COO
# 18      Marty       Bohn             None                         Founder
# 19      Kevin    Pursley             None                Managing Partner
# 20      Steve      Huber             None  Vice President Of Professional
# 21       Troy    Richard             None                Managing Partner
# 22       Mike      Byrne  +1 585 242 9999                Managing Partner
# 23      Lewis      Airth             None               National Director
# 24        Amy      Smith  +1 646 922 7768        Assistant Vice President
# 25     Andrew      Flach  +1 973 769 3914                         Founder
# 26      Emily   Johnston  +1 973 647 4177                             CEO
# 27      Laura    Simpson  +1 973 850 7319                Advisor Software
# 28       Lisa     Aldape  +1 973 525 6550               Advisory Services
# 29  Alexandra  Attanasio  +1 646 838 5440                Managing Partner
# 30      Karen  Pellicone  +1 973 850 7311                             CAO
#
#     Department Twitter handle  \
# 0   management           None
# 1   management           None
# 2   management           None
# 3   management           None
# 4    executive           None
# 5    executive           None
# 6    executive           None
# 7   operations           None
# 8    executive           None
# 9   management           None
# 10  management           None
# 11  operations           None
# 12  management           None
# 13  operations           None
# 14   executive           None
# 15   executive           None
# 16   executive           None
# 17   executive           None
# 18   executive           None
# 19  management           None
# 20   executive           None
# 21  management           None
# 22  management           None
# 23  management           None
# 24  operations           None
# 25   executive           None
# 26   executive           None
# 27          it           None
# 28  operations           None
# 29  management           None
# 30  management           None
#
#                                          LinkedIn URL Verification
# 0                                                None        valid
# 1                                                None   accept_all
# 2                                                None   accept_all
# 3                                                None        valid
# 4                                                None        valid
# 5   https://www.linkedin.com/pub/gail-reichwald/5/...        valid
# 6                                                None        valid
# 7                                                None        valid
# 8                                                None        valid
# 9                                                None        valid
# 10                                               None        valid
# 11                                               None        valid
# 12                                               None        valid
# 13                                               None         None
# 14                                               None        valid
# 15                                               None        valid
# 16                                               None        valid
# 17                                               None        valid
# 18                                               None        valid
# 19                                               None        valid
# 20                                               None        valid
# 21                                               None        valid
# 22                                               None        valid
# 23                                               None        valid
# 24                                               None   accept_all
# 25                                               None   accept_all
# 26                                               None   accept_all
# 27                                               None   accept_all
# 28                                               None   accept_all
# 29                                               None   accept_all
# 30                                               None   accept_all
# Total 31 emails found.
